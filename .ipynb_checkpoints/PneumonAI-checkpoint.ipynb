# %% [markdown]
# # PneumonAI
# This notebook implements and experiments with PneumonAI. This AI is tasked to classify Chest X-Ray in two categories : PNEUMONIA or Normal and was trained on the [Chest X-Ray Images (Pneumonia)](https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia) and [NIH Chest X-rays](https://www.kaggle.com/datasets/nih-chest-xrays/data), both available on Kaggle.

# %% [markdown]
# ## Import packages and loading the datasets
# Note that the preprocessing has been reworked beforehand.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
 
# get current directory
path = os.getcwd()
# parent directory
parent = os.path.dirname(path)

# Loads and returns child & adult datasets
# Output : raw sets in the following order : raining, validation and testing sets.
def load_both_datasets() :
    # Fix sizes
    BATCH_SIZE = 32
    IMG_SIZE = (512, 512)

    # Child dataset
    train = keras.utils.image_dataset_from_directory(parent+"/chest_xray/training1", labels='inferred', color_mode = 'rgb', batch_size=BATCH_SIZE, image_size=IMG_SIZE, pad_to_aspect_ratio = True)
    val = keras.utils.image_dataset_from_directory(parent+"/chest_xray/validation1", labels='inferred', color_mode = 'rgb', batch_size=BATCH_SIZE, image_size=IMG_SIZE, pad_to_aspect_ratio = True)
    test = keras.utils.image_dataset_from_directory(parent+"/chest_xray/test", labels='inferred', color_mode = 'rgb', batch_size=BATCH_SIZE, image_size=IMG_SIZE, pad_to_aspect_ratio = True)
    
    # Adult dataset
    trainadult = keras.utils.image_dataset_from_directory(parent+"/NIH Lungs/Only_control/train", labels='inferred', color_mode = 'rgb', batch_size=BATCH_SIZE, image_size=IMG_SIZE, pad_to_aspect_ratio = True)
    valadult = keras.utils.image_dataset_from_directory(parent+"/NIH Lungs/Only_control/val", labels='inferred', color_mode = 'rgb', batch_size=BATCH_SIZE, image_size=IMG_SIZE, pad_to_aspect_ratio = True)
    testadult = keras.utils.image_dataset_from_directory(parent+"/NIH Lungs/Only_control/test", labels='inferred', color_mode = 'rgb', batch_size=BATCH_SIZE, image_size=IMG_SIZE, pad_to_aspect_ratio = True)

    return train, val, test, trainadult, valadult, testadult

# Returns the dataset preprocessed with data augmentation applied on the training set
# Input : train, val and test : unpreprocessed tf.data.Dataset containing respectively the training, validation and testing sets.
# Output : preprocessed sets in the following order : raining, validation and testing sets.
def preprocessing_and_data_augmentation(train, val, test) :
    AUTOTUNE = tf.data.AUTOTUNE
    seed = (1, 2)

    # Preprocess and apply data augmenation to train set
    train_dataset = train.map(lambda img, label: (keras.applications.mobilenet_v2.preprocess_input(img), label), num_parallel_calls = AUTOTUNE)
    train_dataset = train_dataset.map(lambda x, label:(tf.image.stateless_random_contrast(x, 0.2, 0.5, seed), label), num_parallel_calls = AUTOTUNE)
    train_dataset = train_dataset.map(lambda x, label:(tf.image.stateless_random_saturation(x, 0.5, 1.0, seed), label), num_parallel_calls = AUTOTUNE)

    # Preprocess validation and testing
    validation_dataset = val.map(lambda img, label: (keras.applications.mobilenet_v2.preprocess_input(img), label), num_parallel_calls = AUTOTUNE)
    test_dataset = test.map(lambda img, label: (keras.applications.mobilenet_v2.preprocess_input(img), label), num_parallel_calls = AUTOTUNE)

    # Prefectching allows for better performance
    train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
    val_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
    test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

    return train_dataset, val_dataset, test_dataset
# Out:
# 2024-05-26 22:08:48.453982: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-26 22:08:48.653662: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-26 22:08:48.653707: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-26 22:08:48.687084: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-26 22:08:48.756043: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-26 22:08:49.417262: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
train, val, test, trainadult, valadult, testadult = load_both_datasets()
train_dataset, val_dataset, test_dataset = preprocessing_and_data_augmentation(train, val, test)
trainadult_dataset, valadult_dataset, testadult_dataset = preprocessing_and_data_augmentation(trainadult, valadult, testadult)
# Out:
# Found 4105 files belonging to 2 classes.
# 2024-05-26 22:08:59.544702: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-26 22:08:59.651845: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-26 22:08:59.651879: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-26 22:08:59.654345: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-26 22:08:59.654368: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-26 22:08:59.654378: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-26 22:08:59.917995: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-26 22:08:59.918051: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-26 22:08:59.918057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-05-26 22:08:59.918076: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-26 22:08:59.918107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13553 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2024-05-26 22:09:00.370879: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Found 1111 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.
# Found 676 files belonging to 2 classes.
# Found 84 files belonging to 2 classes.
# Found 84 files belonging to 2 classes.

# %% [markdown]
# ## Model Creation

# %%
# Creates and returns a model using transfer learning from the argument base_model.
# Input : base_model, a pretrained model from keras.applications to use as backbone
# Output : the new model with backbone parameters frozen
def create_model(base_model) :
    inputs = base_model.inputs
    x = base_model.outputs[0]
    base_model.trainable=False
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    x = global_average_layer(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    prediction_layer = tf.keras.layers.Dense(1)
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)
    base_learning_rate = 0.0001
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## Model Training

# %%
# Trains the model
# Inputs :
#   - model : the model to train
#   - train_dataset : the training set
#   - validation_dataset : the validation set
#   - initial_epochs : the maximal number of epochs
# Output : history of the training
def train_model(model, train_dataset, validation_dataset, initial_epochs = 100) :
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',patience=3, verbose=False)
    history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset, callbacks=[callback], verbose=False)
    return history

# %% [markdown]
# ## Model Fine-Tuning

# %%
# Unfreeze the backbone for fine tuning.
# Input : base_model : the backbone.
def unfreeze_model(base_model) :
    base_model.trainable=True

# Trains the model
# Inputs :
#   - model : the model to fine tune
#   - train_dataset : the training set
#   - validation_dataset : the validation set
#   - initial_epochs : the maximal number of epochs
# Output : history of the training
def fine_tune_model(model, train_dataset, validation_dataset, max_epochs = 100, min_lr=0.000001) :
    unfreeze_model(base_model)
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',patience=10, verbose=False)
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=min_lr)
    history = model.fit(train_dataset,
                    epochs=max_epochs,
                    validation_data=validation_dataset, callbacks=[callback, reduce_lr], verbose=False)
    return history

# %% [markdown]
# ## GradCam
# From [Grad-CAM class activation visualization](https://keras.io/examples/vision/grad_cam/), with a few modifications to fit our needs.

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # Create a sub-model that outputs the feature maps and final prediction
    grad_model = tf.keras.models.Model(
        model.inputs, [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Use GradientTape to record gradients
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)

        # If pred_index is not specified, use the predicted class index
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # Calculate gradients
    grads = tape.gradient(class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # Compute the heatmap
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # Normalise the heatmap
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)

    return heatmap.numpy()

# Display
from IPython.display import Image, display
import matplotlib as mpl
def display_gradcam(img, heatmap, cam_path="cam.jpg", alpha=0.001):

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = mpl.colormaps["jet"]

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.utils.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.utils.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = img + jet_heatmap * alpha 
    superimposed_img = keras.utils.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))

# %% [markdown]
# ### Extract Bounding Boxes
# We accept having multiple boxes, as pneumonias can be multifocal (i.e. be visible in multiple unrelated areas of the chest). The algorithm is fairly naive and clusters together neighboring positive pixels.

# %%
# Extract Bounding Boxes from the GradCAM Heatmap
# Inputs :
#   - heatmap : GradCAM Heatmap
# Output : a set containing coordinates from the top left and bottom right corners of the bounding boxe(s)
def ExtractBB(heatmap) :
    # Binarize the set
    binarization = 1*(heatmap>=0.5)
    positive = set()
    for i in range(len(binarization)) :
        for j in range(len(binarization[i])) :
            if binarization[i][j] == 1 :
                positive.add((i, j))
    # cluster zones together
    clusters = set()
    while len(positive)>0 :
        cluster = set()
        # Get a coordinate
        coord = list(positive)[0]
        # Add the initial pixel to the new cluster
        cluster.add(coord)
        # Remove it from positive to avoid treating it twice
        positive.remove(coord)
        # Start Growing the region
        get_next_to(heatmap, positive, coord, cluster)
        # Create the bounding box containing all the needed pixels
        mini = len(heatmap)
        minj = len(heatmap[0])
        maxi = 0
        maxj = 0
        for elem in cluster :
            mini = min(mini, elem[0])
            minj = min(minj, elem[1])
            maxi = max(maxi, elem[0])
            maxj = max(maxj, elem[1])
        # add the cluster to the set
        clusters.add((mini, minj, maxi, maxj))
    return clusters

# Checks Neighbooring pixels recursively until the cluster is bordered by negative pixels. Updated positive and cluster in the process.
# Inputs :
#   - heatmap : GradCAM Heatmap
#   - positive : set of unchecked coordinates of positive pixels
#   - coord : Coordinates whose neightboor must be checked
#   - cluster : Set containing coordinates of pixels in the cluster
# Output : /
def get_next_to(heatmap, positive, coord, cluster) :
    if coord[0] > 0 :
        newcoord = (coord[0]-1, coord[1])
        update(heatmap, positive, newcoord, cluster)
        if coord[1] > 0 :
            newcoord = (coord[0]-1, coord[1]-1)
            update(heatmap, positive, newcoord, cluster)
        if coord[1] < len(heatmap[coord[0]])-1 :
            newcoord = (coord[0]-1, coord[1]+1)
            update(heatmap, positive, newcoord, cluster)
    if coord[0] < len(heatmap)-1 :
        newcoord = (coord[0]+1, coord[1])
        update(heatmap, positive, newcoord, cluster)
        if coord[1] > 0 :
            newcoord = (coord[0]+1, coord[1]-1)
            update(heatmap, positive, newcoord, cluster)
        if coord[1] < len(heatmap[coord[0]])-1 :
            newcoord = (coord[0]+1, coord[1]+1)
            update(heatmap, positive, newcoord, cluster)
    if coord[1] > 0 :
        newcoord = (coord[0], coord[1]-1)
        update(heatmap, positive, newcoord, cluster)
    if coord[1] < len(heatmap[coord[0]])-1 :
        newcoord = (coord[0], coord[1]+1)
        update(heatmap, positive, newcoord, cluster)

# Updates positive and clusters if newcoords contains the coordinates of a positive pixel.
# Inputs :
#   - heatmap : GradCAM Heatmap
#   - positive : set of unchecked coordinates of positive pixels
#   - coord : Coordinates whose neightboor must be checked
#   - cluster : Set containing coordinates of pixels in the cluster
# Output : /
def update(heatmap, positive, newcoord, cluster) :
    if newcoord in positive :
        # Add positive neighboor to the cluster
        cluster.add(newcoord)
        # Remove it from positive to avoid treating it twice
        positive.remove(newcoord)
        # Check its own neighboor
        get_next_to(heatmap, positive, newcoord, cluster)

# %% [markdown]
# ## Compute IoU (Intersection over Union)
# From [Intersection over Union (IoU) for object detection](https://pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/), adapted for multiple bounding boxes.

# %%
def bb_intersection_over_union(boxesA, boxesB):
    interArea = 0
    boxesAArea = 0
    boxesBArea = 0
    for boxA in boxesA :
        boxesAArea += (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
        for boxB in boxesB :
            # determine the (x, y)-coordinates of the intersection rectangle
            xA = max(boxA[0], boxB[0])
            yA = max(boxA[1], boxB[1])
            xB = min(boxA[2], boxB[2])
            yB = min(boxA[3], boxB[3])
            # compute the area of intersection rectangle
            interArea += max(0, xB - xA + 1) * max(0, yB - yA + 1)
            # compute the area of both the prediction and ground-truth
            # rectangles
    for boxB in boxesB :
        boxesBArea += (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)
    # compute the intersection over union by taking the intersection
    # area and dividing it by the sum of prediction + ground-truth
    # areas - the interesection area
    iou = interArea / float(boxesAArea + boxesBArea - interArea)
    # return the intersection over union value
    return iou

# %% [markdown]
# # Experiments
# Now that we implemented every tool we need, we can show the code used to build and experiments with PneumonAI.

# %% [markdown]
# ### Children Model Traning and evaluation

# %% [markdown]
# Initial training of the additional layers :

# %%
IMG_SHAPE = (None, None) + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

model = create_model(base_model)
print(model.evaluate(train_dataset, verbose=0))
print(model.evaluate(val_dataset, verbose=0))
print(model.evaluate(test_dataset, verbose=0))
train_history = train_model(model, train_dataset, val_dataset)
# Out:
# /tmp/ipykernel_3493/1677580244.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
# 2024-05-26 20:08:46.891248: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# [0.7782465219497681, 0.26065772771835327]
# [0.853820264339447, 0.24212421476840973]
# [0.8070282936096191, 0.375]
# 2024-05-26 20:09:00.650881: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:09:11.991239: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:09:20.467949: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:09:28.571748: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:09:37.255345: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:09:45.697102: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:09:54.030860: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:10:02.266728: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:10:11.531729: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:10:20.079826: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:10:28.602521: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:10:37.040546: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:10:45.209372: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:10:53.479629: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:11:01.633463: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:11:09.858197: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:11:18.311490: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:11:26.873103: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:11:36.724519: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:11:46.157247: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:11:55.037612: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:12:04.087473: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:12:13.191690: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:12:22.149296: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:12:31.040661: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:12:39.975435: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:12:48.859882: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:12:57.909985: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:13:06.765299: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:13:15.560359: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:13:24.531720: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:13:33.536769: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:13:42.498278: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:13:51.567759: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size

# %%
acc = train_history.history['accuracy']
val_acc = train_history.history['val_accuracy']

loss = train_history.history['loss']
val_loss = train_history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('A. Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim([0,1.0])
plt.title('B. Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
acc = train_history.history['accuracy']
val_acc = train_history.history['val_accuracy']

loss = train_history.history['loss']
val_loss = train_history.history['val_loss']

print(acc[-1])
print(val_acc[-1])
print(loss[-1])
print(val_loss[-1])
print(len(loss))
print(model.evaluate(test_dataset, verbose=0))
# Out:
# 0.9478684663772583
# 0.8910890817642212
# 0.1407625377178192
# 0.21122652292251587
# 34
# [0.35036003589630127, 0.8685897588729858]

# %%
model.save("PneumonAI.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
unfreeze_model(base_model)
fine_tune_history = fine_tune_model(model, train_dataset, val_dataset)
print(model.evaluate(test_dataset, verbose=0)[1])
# Out:
# 2024-05-26 20:26:11.950830: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:26:21.040216: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:26:30.105607: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:26:39.287623: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:26:48.280190: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:26:57.088551: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:27:06.023586: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:27:14.990901: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:27:23.963669: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:27:34.196912: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:27:42.921665: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:27:51.928110: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:28:00.922259: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:28:09.984289: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:28:18.946246: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:28:27.767410: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:28:36.808488: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:28:45.814686: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:28:55.262081: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:29:04.439072: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:29:13.503860: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:29:22.641393: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:29:31.525855: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:29:40.649548: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:29:49.258514: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:29:58.997462: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:30:07.832476: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:30:16.837806: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:30:26.040988: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:30:35.044926: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:30:43.977764: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:30:52.786034: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:31:01.924976: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:31:10.810986: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:31:19.638028: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:31:28.465246: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:31:36.980377: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:31:46.202838: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:31:55.792530: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:32:04.684954: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:32:13.744993: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:32:22.492258: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:32:31.729578: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:32:41.098339: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:32:50.041114: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:32:59.815719: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:33:08.983030: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:33:18.018072: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:33:26.905576: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:33:36.130691: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:33:45.031578: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:33:54.083088: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:34:03.058427: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:34:11.943221: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:34:21.592681: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:34:30.468319: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:34:39.450678: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:34:48.660602: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:34:57.553812: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:35:06.727598: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:35:16.571830: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:35:25.591801: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:35:34.453253: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:35:43.439110: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:35:52.417553: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:36:01.286396: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:36:10.131463: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 0.8637820482254028

# %%
acc = fine_tune_history.history['accuracy']
val_acc = fine_tune_history.history['val_accuracy']

loss = fine_tune_history.history['loss']
val_loss = fine_tune_history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('A. Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim([0,1.0])
plt.title('B. Training and Validation Loss')
plt.xlabel('epoch')
plt.show()


print(acc[-1])
print(val_acc[-1])
print(loss[-1])
print(val_loss[-1])
print(len(loss))

print(model.evaluate(test_dataset, verbose=0))
# Out:
# 0.9639464020729065
# 0.9162916541099548
# 0.09296617656946182
# 0.15824367105960846
# 67
# [0.35106807947158813, 0.8637820482254028]

# %% [markdown]
# ### Knowledge transfert

# %% [markdown]
# Healthy target

# %%
IMG_SHAPE = (None, None) + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
for j in range(1,4) :
    train_acc = []
    val_acc = []
    test_acc = []
    training = train_dataset
    validation = val_dataset
    trainingft = train_dataset
    validationft = val_dataset
    train_type = "child"
    fine_tune_type = "child"
    if j % 2 != 0 :
        train_type = "adult"
        training = trainadult_dataset
        validation = valadult_dataset
    if j >= 2 :
        fine_tune_type = "adult"
        trainingft = trainadult_dataset
        validationft = valadult_dataset
    print("Training with : " + train_type)
    print("Fine-Tuning with : " + fine_tune_type)
    for i in range(1) :
        #print("Training number : " + str(i+1))
        model = create_model(base_model)
        train_history = train_model(model, training, validation)
        unfreeze_model(base_model)
        fine_tune_history = fine_tune_model(model, trainingft, validationft)
        if j == 0 :
            train_acc.append(fine_tune_history.history['accuracy'][-1])
            val_acc.append(fine_tune_history.history['val_accuracy'][-1])
            test_acc.append(model.evaluate(test_dataset, verbose=0)[1])
        else :
            train_acc.append(model.evaluate(trainadult_dataset, verbose=0)[1])
            val_acc.append(model.evaluate(valadult_dataset, verbose=0)[1])
            test_acc.append(model.evaluate(testadult_dataset, verbose=0)[1])
    print("Training with : " + train_type)
    print("Fine-Tuning with : " + fine_tune_type)
    print("Results :")
    print("Training Accuracy: " + str(train_acc))
    print("Validation Accuracy: " + str(val_acc))
    print("Testing Accuracy: " + str(test_acc))
# Out:
# /tmp/ipykernel_110509/3197743124.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
# Training with : adult
# Fine-Tuning with : child
# 2024-05-26 22:09:07.675042: I external/local_xla/xla/service/service.cc:168] XLA service 0x5603d2e0e2b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-26 22:09:07.675122: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti SUPER, Compute Capability 8.9
# 2024-05-26 22:09:08.052463: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-26 22:09:08.390185: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716754158.981495  116050 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-05-26 22:10:27.713466: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:10:36.622447: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:10:45.399044: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:10:54.443995: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:11:03.588428: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:11:21.557938: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:11:39.514151: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:11:48.289749: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:11:57.149958: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:12:05.978404: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:12:14.845608: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:12:23.627630: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:12:32.445590: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:12:50.085280: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:13:07.771421: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:13:25.518040: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:13:43.486075: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:14:01.521507: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:14:10.365897: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:14:19.416028: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:14:28.360230: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:14:37.339222: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:15:04.503927: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:15:13.475093: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:15:22.600912: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:15:31.702875: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:15:40.921608: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:16:00.029397: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:16:09.042994: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:16:18.124558: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:16:27.179375: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:16:36.305517: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:17:24.963667: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:18:59.846229: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:19:17.984512: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:19:27.037295: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:19:36.033608: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:19:44.993599: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:19:53.858201: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:20:02.801651: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:20:11.772649: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:20:20.692041: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:20:29.534361: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:20:47.511386: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:20:56.529561: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:21:05.302038: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:21:14.107898: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:21:32.125735: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:21:41.213404: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:21:50.216596: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:21:59.936798: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:22:08.988330: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:22:27.022534: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:22:36.070749: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:22:45.095791: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:22:54.070827: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:23:02.903889: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:23:11.727731: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:23:21.243622: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:23:29.913504: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:23:38.674800: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:23:47.414181: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:23:56.223875: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:24:05.031083: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:24:13.862460: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:24:22.691398: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:24:48.996591: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:24:57.817649: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:25:06.604908: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:25:24.236951: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:25:32.981581: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:25:41.747169: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:25:50.603047: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:25:59.404139: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:26:08.197396: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:26:16.973566: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Training with : adult
# Fine-Tuning with : child
# Results :
# Training Accuracy: [0.5251479148864746]
# Validation Accuracy: [0.5952380895614624]
# Testing Accuracy: [0.511904776096344]
# Training with : child
# Fine-Tuning with : adult
# 2024-05-26 22:26:29.641203: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:26:43.000770: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:26:51.875755: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:27:00.832703: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:27:09.804968: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:27:18.752070: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:27:27.827937: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:27:36.693749: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:27:45.565987: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:27:54.539331: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:28:03.511318: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:28:12.492342: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:28:21.482555: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:28:30.519640: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:28:39.425146: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:28:48.200201: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:28:57.078122: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:29:05.839313: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:29:14.695547: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:29:23.642688: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:29:32.668347: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:29:41.616207: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:29:51.317071: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:30:00.193473: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:30:09.412727: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:30:18.329596: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:30:27.269078: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:30:36.111107: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:30:45.016734: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:30:53.952229: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:02.772609: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:06.320167: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:07.951779: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:10.522656: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:12.274864: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:17.083615: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:18.723960: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:20.328274: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:23.541195: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:25.120736: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:26.757426: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:29.958340: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:31.547077: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:33.147441: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:37.927631: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:39.538011: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:41.130513: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:42.736462: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:44.340280: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:45.928321: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:49.244975: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:50.836278: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:52.452698: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:54.089189: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:55.695242: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:31:58.979063: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:00.594087: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Training with : child
# Fine-Tuning with : adult
# Results :
# Training Accuracy: [0.6834319233894348]
# Validation Accuracy: [0.5357142686843872]
# Testing Accuracy: [0.5714285969734192]
# Training with : adult
# Fine-Tuning with : adult
# 2024-05-26 22:32:04.769846: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:10.913044: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:14.234724: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:15.859078: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:17.472313: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:20.707916: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:22.362495: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:24.886830: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:26.457975: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:30.633441: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:32.267703: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:35.449563: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:37.040518: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:38.661045: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:41.827014: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:43.468416: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:45.088970: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:46.671118: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:48.295250: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:49.912287: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:51.543521: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:56.335392: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:57.912327: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:32:59.520023: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:33:01.177265: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:33:02.822001: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:33:04.400266: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:33:07.632233: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:33:09.262887: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 22:33:10.850163: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Training with : adult
# Fine-Tuning with : adult
# Results :
# Training Accuracy: [0.7041420340538025]
# Validation Accuracy: [0.523809552192688]
# Testing Accuracy: [0.7142857313156128]

# %% [markdown]
# Complex target

# %%
IMG_SHAPE = (None, None) + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
for j in range(1,4) :
    train_acc = []
    val_acc = []
    test_acc = []
    training = train_dataset
    validation = val_dataset
    trainingft = train_dataset
    validationft = val_dataset
    train_type = "child"
    fine_tune_type = "child"
    if j % 2 != 0 :
        train_type = "adult"
        training = trainadult_dataset
        validation = valadult_dataset
    if j >= 2 :
        fine_tune_type = "adult"
        trainingft = trainadult_dataset
        validationft = valadult_dataset
    print("Training with : " + train_type)
    print("Fine-Tuning with : " + fine_tune_type)
    for i in range(1) :
        #print("Training number : " + str(i+1))
        model = create_model(base_model)
        train_history = train_model(model, training, validation)
        unfreeze_model(base_model)
        fine_tune_history = fine_tune_model(model, trainingft, validationft)
        if j == 0 :
            train_acc.append(fine_tune_history.history['accuracy'][-1])
            val_acc.append(fine_tune_history.history['val_accuracy'][-1])
            test_acc.append(model.evaluate(test_dataset, verbose=0)[1])
        else :
            train_acc.append(model.evaluate(trainadult_dataset, verbose=0)[1])
            val_acc.append(model.evaluate(valadult_dataset, verbose=0)[1])
            test_acc.append(model.evaluate(testadult_dataset, verbose=0)[1])
    print("Training with : " + train_type)
    print("Fine-Tuning with : " + fine_tune_type)
    print("Results :")
    print("Training Accuracy: " + str(train_acc))
    print("Validation Accuracy: " + str(val_acc))
    print("Testing Accuracy: " + str(test_acc))
# Out:
# /tmp/ipykernel_3493/3197743124.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
# Training with : adult
# Fine-Tuning with : child
# 2024-05-26 20:54:29.236193: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:34.267888: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:34.290785: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:35.952941: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:36.120908: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:37.341932: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:37.362624: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:37.618059: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:37.774719: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:38.903090: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:38.924834: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:39.208508: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:39.374348: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:40.549878: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:40.572338: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:40.855914: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:40.992654: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:42.149565: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:42.170878: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:42.437510: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:42.590964: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:43.721305: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:43.743580: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:44.039260: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:44.242285: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:45.371582: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:45.393697: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:45.666505: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:45.846892: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:46.988128: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:47.011854: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:47.272627: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:47.408980: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:48.613390: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:48.634921: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:48.978470: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:49.137727: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:58.007727: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:54:58.026186: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:01.463707: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:01.625186: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:08.854754: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:08.880400: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:11.671773: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:11.801714: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:18.994063: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:19.016639: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:20.824307: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:20.984734: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:28.180379: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:28.203120: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:30.019402: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:30.152831: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:37.316415: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:37.335145: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:39.145618: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:39.319674: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:46.452965: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:46.474606: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:48.252647: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:48.398596: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:55.594581: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:55.619546: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:57.423422: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:55:57.563961: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:04.849426: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:04.871422: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:06.672290: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:06.809770: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:13.939195: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:13.964717: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:15.730360: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:15.864096: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:22.996756: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:23.020328: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:24.815745: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:24.948486: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:32.051568: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:32.069917: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:33.832075: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:33.972660: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:41.113228: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:41.134826: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:42.985144: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:43.110827: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:50.396432: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:50.415130: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:52.193928: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:52.330452: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:59.517655: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:56:59.541784: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:01.349063: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:01.480597: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:08.697300: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:08.720035: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:10.530477: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:10.684084: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:17.807096: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:17.824478: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:19.616195: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:19.703116: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:26.915046: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:26.938781: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:28.730927: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:28.866719: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:36.029780: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:36.046987: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:37.858633: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:37.999196: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:45.127269: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:45.145234: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:46.932158: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:47.075771: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:54.133869: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:54.151245: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:55.981886: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:57:56.134412: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:03.260118: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:03.277272: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:05.064168: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:05.209326: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:12.351622: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:12.371428: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:14.199394: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:14.342097: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:21.502009: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:21.521260: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:23.344466: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:23.472126: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:30.653145: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:30.670760: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:32.495251: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:32.615798: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:39.743284: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:39.761243: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:41.548581: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:41.708319: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 20:58:48.909524: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# ...
# 2024-05-26 21:26:07.231442: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:08.377733: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:08.399567: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:08.683887: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:08.840238: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:09.977574: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:09.999141: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:10.287673: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:10.431017: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:11.582487: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:11.604313: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:11.868447: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:12.005863: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:13.137452: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:13.159368: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:13.418527: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:13.568132: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:14.715724: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:14.737442: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:14.999824: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:15.135711: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:16.290629: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:16.312283: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:16.587354: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:16.691008: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:17.844417: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:17.866205: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:18.144345: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:18.283191: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:19.439020: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:19.461344: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:19.735886: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:19.850174: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:21.024805: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:21.046579: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:21.319396: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:21.536481: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:22.650072: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:22.671749: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:22.935785: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:23.089594: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:25.320555: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:25.344701: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# Training with : adult
# Fine-Tuning with : adult
# Results :
# Training Accuracy: [0.6612426042556763]
# Validation Accuracy: [0.523809552192688]
# Testing Accuracy: [0.6428571343421936]
# 2024-05-26 21:26:25.533326: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-05-26 21:26:25.555946: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 100663424 bytes after encountering the first element of size 100663424 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
